# %%
import pandas
hotel=pandas.read_csv('C:/Users/wade z shao/Downloads/511638_944030_compressed_hotel_bookings/hotel_bookings.csv')
hotel.shape
# Out:
# (119390, 32)

# %%
hotel.head()
# Out:
#           hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0  Resort Hotel            0  ...           Check-Out               2015-07-01
# 1  Resort Hotel            0  ...           Check-Out               2015-07-01
# 2  Resort Hotel            0  ...           Check-Out               2015-07-02
# 3  Resort Hotel            0  ...           Check-Out               2015-07-02
# 4  Resort Hotel            0  ...           Check-Out               2015-07-03
#
# [5 rows x 32 columns]

# %%
hotel.describe()
# Out:
#          is_canceled  ...  total_of_special_requests
# count  119390.000000  ...              119390.000000
# mean        0.370416  ...                   0.571363
# std         0.482918  ...                   0.792798
# min         0.000000  ...                   0.000000
# 25%         0.000000  ...                   0.000000
# 50%         0.000000  ...                   0.000000
# 75%         1.000000  ...                   1.000000
# max         1.000000  ...                   5.000000
#
# [8 rows x 20 columns]

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
#观察租赁额密度分布
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
fig.set_size_inches(6,5)
sns.distplot(hotel['arrival_date_week_number'])

ax.set(xlabel='arrival_date_week_number',title='Distribution of arrival_date_week_number',)
# Out:
# [Text(0.5, 0, 'arrival_date_week_number'),
#  Text(0.5, 1.0, 'Distribution of arrival_date_week_number')]
