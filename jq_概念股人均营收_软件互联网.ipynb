# %%
import jqdatasdk
from jqdatasdk import *
jqdatasdk.auth("13141315365", "315365")
# Out:
# 提示：当前环境pandas版本为0.25，get_price与get_fundamentals_continuously接口panel参数将固定为False
# 注意：0.25以上版本pandas不支持panel，如使用该数据结构和相关函数请注意修改
# auth success

# %% [markdown]
# ## 软件与互联网
# GN1000	金融科技	2018-02-05
#
# GN1001	ERP软件	2018-02-06
#
# GN099	移动互联网	2013-12-31
#
# GN080	网络游戏	2013-12-31
#
# GN030	物联网	2013-12-31
#
# GN1014	工业互联网	2018-03-02
#
# GN156	在线教育	2014-01-29
#
# GN163	在线旅游	2014-02-26
#
# GN210	智慧城市	2020-04-03

# %%
for i in [1000,1001,99]:#金融科技 ERP软件 移动互联网
    conceptno='GN'+str(i).rjust(3,'0') # 加载概念股清单
    print('********',conceptno,'********')
    yuangong2=pandas.DataFrame(columns=['code'])
    try:    
        stocks=get_concept_stocks(conceptno, date=None) # 员工人数
        for code1 in stocks: 
            yuangong0=finance.run_query(query(finance.STK_EMPLOYEE_INFO.name,finance.STK_EMPLOYEE_INFO.code,finance.STK_EMPLOYEE_INFO.employee).filter(finance.STK_EMPLOYEE_INFO.code==code1,finance.STK_EMPLOYEE_INFO.pub_date>='2019-12-01').limit(10))
            yuangong1=finance.run_query(query(finance.STK_INCOME_STATEMENT.code,finance.STK_INCOME_STATEMENT.total_operating_revenue,finance.STK_INCOME_STATEMENT.net_profit).filter(finance.STK_INCOME_STATEMENT.code==code1,finance.STK_INCOME_STATEMENT.end_date=='2019-12-31').limit(1000))
            import pandas# 将两个表连接起来
            yuangong3=pandas.merge(yuangong0,yuangong1)
            yuangong3=pandas.concat([yuangong2,yuangong3])
            yuangong2=yuangong3
        print(yuangong2)   
        yuangong2.plot('employee','net_profit',kind='scatter')      
    except:
        print("~~~~~",conceptno)
        pass
# Out:
# ******** GN1000 ********
#           code  employee  name    net_profit  total_operating_revenue
# 0  000555.XSHE   10209.0  神州信息  3.815529e+08             1.014601e+10
# 0  000889.XSHE    5811.0  中嘉博创 -1.240169e+09             3.162631e+09
# 0  000948.XSHE    5916.0  南天信息  8.347817e+07             3.303367e+09
# 0  000977.XSHE    5469.0  浪潮信息  9.553896e+08             5.165328e+10
# 0  000997.XSHE    6224.0   新大陆  7.228319e+08             6.181535e+09
# 0  002017.XSHE    1781.0  东信和平  3.963995e+07             1.178720e+09
# 0  002065.XSHE    8991.0  东华软件  5.777425e+08             8.849013e+09
# 0  002104.XSHE    1377.0  恒宝股份  8.703312e+07             1.535467e+09
# 0  002152.XSHE   26018.0  广电运通  8.833769e+08             6.496265e+09
# 0  002177.XSHE     344.0  御银股份  6.727771e+07             2.139720e+08
# 0  002195.XSHE     823.0  二三四五  7.698701e+08             2.440761e+09
# 0  002197.XSHE    1239.0  证通电子  1.515143e+07             1.339614e+09
# ...

# %% [markdown]
# GN080	网络游戏	2013-12-31
#
# GN030	物联网	2013-12-31
#
# GN1014	工业互联网	2018-03-02

# %%
for i in [80,30,1014]:
    conceptno='GN'+str(i).rjust(3,'0') # 加载概念股清单
    print('********',conceptno,'********')
    yuangong2=pandas.DataFrame(columns=['code'])
    try:    
        stocks=get_concept_stocks(conceptno, date=None) # 员工人数
        for code1 in stocks: 
            yuangong0=finance.run_query(query(finance.STK_EMPLOYEE_INFO.name,finance.STK_EMPLOYEE_INFO.code,finance.STK_EMPLOYEE_INFO.employee).filter(finance.STK_EMPLOYEE_INFO.code==code1,finance.STK_EMPLOYEE_INFO.pub_date>='2019-12-01').limit(10))
            yuangong1=finance.run_query(query(finance.STK_INCOME_STATEMENT.code,finance.STK_INCOME_STATEMENT.total_operating_revenue,finance.STK_INCOME_STATEMENT.net_profit).filter(finance.STK_INCOME_STATEMENT.code==code1,finance.STK_INCOME_STATEMENT.end_date=='2019-12-31').limit(1000))
            import pandas# 将两个表连接起来
            yuangong3=pandas.merge(yuangong0,yuangong1)
            yuangong3=pandas.concat([yuangong2,yuangong3])
            yuangong2=yuangong3
        print(yuangong2)   
        yuangong2.plot('employee','net_profit',kind='scatter')     
    except:
        print("~~~~~",conceptno)
        pass
# Out:
# ******** GN080 ********
#           code  employee  name    net_profit  total_operating_revenue
# 0  002148.XSHE     237.0  北纬科技 -3.221297e+07             1.724357e+08
# 0  002174.XSHE    1846.0  游族网络  2.564159e+08             3.220502e+09
# 0  002261.XSHE    3842.0  拓维信息  2.139958e+07             1.239736e+09
# 0  002292.XSHE    4217.0  奥飞娱乐  1.040600e+08             2.726920e+09
# 0  002343.XSHE     186.0  慈文传媒  1.567939e+08             1.171427e+09
# 0  002425.XSHE     660.0  凯撒文化  2.099561e+08             8.037028e+08
# 0  002464.XSHE     100.0  众应互联 -1.348431e+09             4.618520e+08
# 0  002517.XSHE    1379.0  恺英网络 -1.794984e+09             2.036876e+09
# 0  002555.XSHE    2818.0  三七互娱  2.416841e+09             1.322714e+10
# 0  002558.XSHE    2039.0  巨人网络  8.542295e+08             2.571433e+09
# 0  002602.XSHE    6527.0  世纪华通  2.735489e+09             1.468972e+10
# 0  002605.XSHE    1148.0  姚记科技  4.428935e+08             1.736596e+09
# ...

# %%
GN156	在线教育	2014-01-29

GN163	在线旅游	2014-02-26

GN210	智慧城市	2020-04-03

# %%
for i in [156,163,210]:
    conceptno='GN'+str(i).rjust(3,'0') # 加载概念股清单
    print('********',conceptno,'********')
    yuangong2=pandas.DataFrame(columns=['code'])
    try:    
        stocks=get_concept_stocks(conceptno, date=None) # 员工人数
        for code1 in stocks: 
            yuangong0=finance.run_query(query(finance.STK_EMPLOYEE_INFO.name,finance.STK_EMPLOYEE_INFO.code,finance.STK_EMPLOYEE_INFO.employee).filter(finance.STK_EMPLOYEE_INFO.code==code1,finance.STK_EMPLOYEE_INFO.pub_date>='2019-12-01').limit(10))
            yuangong1=finance.run_query(query(finance.STK_INCOME_STATEMENT.code,finance.STK_INCOME_STATEMENT.total_operating_revenue,finance.STK_INCOME_STATEMENT.net_profit).filter(finance.STK_INCOME_STATEMENT.code==code1,finance.STK_INCOME_STATEMENT.end_date=='2019-12-31').limit(1000))
            import pandas# 将两个表连接起来
            yuangong3=pandas.merge(yuangong0,yuangong1)
            yuangong3=pandas.concat([yuangong2,yuangong3])
            yuangong2=yuangong3
        print(yuangong2)   
        yuangong2.plot('employee','net_profit',kind='scatter')    
    except:
        print("~~~~~",conceptno)
        pass
# Out:
# ******** GN156 ********
#           code  employee   name    net_profit  total_operating_revenue
# 0  000526.XSHE   14098.0   紫光学大  1.231541e+07             2.991938e+09
# 0  000719.XSHE   14597.0   中原传媒  8.373573e+08             9.498393e+09
# 0  002230.XSHE   10447.0   科大讯飞  9.430705e+08             1.007869e+10
# 0  002261.XSHE    3842.0   拓维信息  2.139958e+07             1.239736e+09
# 0  002308.XSHE    1511.0   威创股份 -1.216814e+09             1.101742e+09
# 0  002325.XSHE    1927.0   洪涛股份  7.975303e+07             4.030648e+09
# 0  002348.XSHE    1156.0   高乐股份 -3.593519e+08             7.124312e+08
# 0  002467.XSHE    1060.0    二六三  1.827101e+08             1.013566e+09
# 0  002599.XSHE    2482.0   盛通股份  1.485751e+08             1.952690e+09
# 0  002621.XSHE     687.0    美吉姆  1.863195e+08             6.298194e+08
# 0  002678.XSHE    2534.0   珠江钢琴  1.871240e+08             2.053456e+09
# 0  002696.XSHE    3284.0   百洋股份 -2.829105e+08             2.844134e+09
# ...

# %%
for i in [80]:
    conceptno='GN'+str(i).rjust(3,'0') # 加载概念股清单
    print('********',conceptno,'********')
    # print(conceptno)
    try:    
        # print('123')
        stocks=get_concept_stocks(conceptno, date=None) # 员工人数
        # print(stocks)
        yuangong1=pandas.DataFrame(columns=['code','day'])
        for code1 in stocks: 
            # print('123')
            # print(code1)
            yuangong0=get_fundamentals(query(valuation.code,valuation.pe_ratio,valuation.market_cap,valuation.day).filter(valuation.code==code1),date='2020-6-14')
            # print(yuangong0)            
            yuangong=pandas.concat([yuangong0,yuangong1])# print('合并后的结果为',yuangong)
            yuangong1=yuangong            
    except:
        print("~~~~~",conceptno)
        pass
print('~~~~~~~~~~~~~~~~~~~~~~~~~')
print(yuangong1)
# Out:
# ******** GN080 ********
# ~~~~~~~~~~~~~~~~~~~~~~~~~
#           code         day  market_cap   pe_ratio
# 0  603444.XSHG  2020-06-14    308.2989    33.5858
# 0  603258.XSHG  2020-06-14    105.4374    36.5033
# 0  600880.XSHG  2020-06-14     54.4479   108.7595
# 0  600640.XSHG  2020-06-14    141.7930   247.9016
# 0  600633.XSHG  2020-06-14    126.6772    28.1814
# 0  600373.XSHG  2020-06-14    163.1497    10.2867
# 0  600226.XSHG  2020-06-14     73.7580    50.5310
# 0  600173.XSHG  2020-06-14     31.8308     7.1039
# 0  300533.XSHE  2020-06-14     51.7742    30.8124
# 0  300518.XSHE  2020-06-14     24.8378   -13.1793
# 0  300494.XSHE  2020-06-14     42.7440    58.1015
# 0  300467.XSHE  2020-06-14     35.5753    -2.8752
# 0  300459.XSHE  2020-06-14     98.5105    -3.5027
# 0  300418.XSHE  2020-06-14    269.6998    18.9418
# 0  300315.XSHE  2020-06-14    196.3329    72.4571
# 0  300311.XSHE  2020-06-14     48.4832   -30.5597
# 0  300299.XSHE  2020-06-14     53.7365    -9.6251
# ...

# %%
yuangong1.plot('market_cap','pe_ratio',kind='scatter')
