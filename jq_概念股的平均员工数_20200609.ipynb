# %% [markdown]
# ## 股票概念哪家强
# 分析800多组概念行业

# %%
import jqdatasdk
from jqdatasdk import *
jqdatasdk.auth("13141315365", "315365")
# Out:
# 提示：当前环境pandas版本为0.25，get_price与get_fundamentals_continuously接口panel参数将固定为False
# 注意：0.25以上版本pandas不支持panel，如使用该数据结构和相关函数请注意修改
# auth success

# %%
get_concepts()
# Out:
#        name start_date
# GN001  参股金融 2013-12-31
# GN028  智能电网 2013-12-31
# GN030   物联网 2013-12-31
# GN031    重组 2013-12-31
# GN032   迪士尼 2013-12-31
# ...     ...        ...
# GN995  轨道交通 2017-10-30
# GN996    钒钛 2017-10-30
# GN997  液晶显示 2019-10-16
# GN998    水泥 2020-03-03
# GN999  染料涂料 2017-10-30
#
# [832 rows x 2 columns]

# %%
for i in range(100,1000):
    conceptno='GN'+str(i)
    # print('********',conceptno,'********')
    # print(conceptno)
    try:    
        stocks=get_concept_stocks(conceptno, date=None)
        # print(stocks)    
        yuan_gong=finance.run_query(query(finance.STK_EMPLOYEE_INFO).filter(finance.STK_EMPLOYEE_INFO.code.in_(stocks)).limit(1000))
        print(conceptno,yuan_gong['employee'].mean())
        # ping_jun_shi_zhi=
    except:
        print("~~~~~",conceptno)
        pass
# Out:
# GN100 1629.0861423220974
# GN101 4679.799043062201
# GN102 7618.95
# GN103 52716.545045045044
# GN104 7900.652307692308
# GN105 1921.9923076923078
# GN106 8708.62970498474
# GN107 4766.742358078603
# GN108 2676.273267326733
# GN109 3399.0917030567684
# GN110 2598.6531791907514
# GN111 2443.712712712713
# GN112 8414.92576419214
# GN113 2438.253846153846
# GN114 2504.320588235294
# GN115 2657.928961748634
# GN116 16335.621176470588
# GN117 2224.795620437956
# GN118 3368.904761904762
# GN119 2661.0299145299145
# GN120 3030.39552238806
# GN121 2353.5658914728683
# GN122 10649.713043478261
# GN123 3444.525974025974
# GN124 2225.9880952380954
# GN125 2577.5521126760564
# GN126 4230.612184249629
# GN127 1931.235294117647
# GN128 7226.091743119266
# GN129 1994.64
# GN130 5674.400793650793
# GN131 2566.6280323450133
# GN132 3078.276
# GN133 2255.019867549669
# GN134 7316.522336769759
# GN135 3546.2520833333333
# GN136 2801.2896825396824
# GN137 12292.471502590673
# GN138 5108.641732283465
# ...

# %%
# 获取概念板块成分股
stocks=get_concept_stocks('GN999', date=None)#老基建
stocks[:6]
# Out:
# ['000565.XSHE',
#  '002010.XSHE',
#  '002256.XSHE',
#  '002361.XSHE',
#  '002440.XSHE',
#  '300067.XSHE']
